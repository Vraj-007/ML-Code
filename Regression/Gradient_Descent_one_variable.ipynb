# %%
from sklearn.datasets import make_regression
import numpy as np

# %%
X, y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1, noise=5)

# %%
X
# Out:
# array([[ 0.95633548],
#        [ 0.3441666 ],
#        [ 1.44883996],
#        [ 1.1449464 ],
#        [-0.65912232],
#        [ 0.9139956 ],
#        [ 2.225337  ],
#        [ 0.07413277],
#        [ 0.06933118],
#        [ 0.78308923],
#        [-0.67232626],
#        [-0.26113901],
#        [-0.05786318],
#        [-1.84850441],
#        [-0.52595466],
#        [-1.03347362],
#        [ 0.40105871],
#        [ 1.22298776],
#        [ 0.02746542],
#        [-1.52775762],
#        [-0.25891257],
#        [ 1.01755159],
#        [ 0.12680095],
#        [-0.24618434],
#        [-0.62743624],
#        [ 0.02476524],
#        [-0.50293279],
#        [-0.43016134],
#        [ 0.80308441],
#        [-0.05065817],
#        [-1.63885101],
#        [ 0.25185367],
#        [-0.24629186],
#        [-0.27168366],
#        [ 0.13946942],
#        [ 1.03726811],
#        [ 1.16185163],
#        [-0.92963302],
#        [ 0.60055745],
#        [-0.14349501],
#        [-1.19202564],
#        [-0.66270344],
#        [-1.73355888],
#        [-1.09097423],
#        [-1.32677453],
#        [-1.75167632],
#        [ 0.7553202 ],
#        [-0.97193996],
#        [-0.11333659],
#        [-0.98839637],
#        [-2.35895483],
#        [ 1.21612327],
#        [-0.06635871],
#        [-0.6645421 ],
#        [-0.29369589],
#        [-0.80134234],
#        [-0.39779574],
#        [ 1.31829617],
#        [ 0.82743876],
#        [-0.08146015],
#        [-1.13931813],
#        [ 0.21585475],
#        [-0.30298582],
#        [ 0.27817527],
#        [-0.78468656],
#        [ 0.03175862],
#        [ 1.35756367],
#        [-0.07614986],
#        [ 0.50506557],
#        [ 1.44940781],
#        [ 0.04379862],
#        [ 0.07481028],
#        [-1.19931584],
#        [ 1.14980079],
#        [-0.36956076],
#        [ 0.20528391],
#        [ 1.87263153],
#        [ 1.44081249],
#        [ 1.07194886],
#        [-0.46995629],
#        [ 1.0241761 ],
#        [-0.92257962],
#        [ 0.91129706],
#        [ 1.08150592],
#        [-0.2756675 ],
#        [ 1.43887037],
#        [-0.07914173],
#        [-0.34457718],
#        [ 0.34255921],
#        [-1.18554375],
#        [-0.15399557],
#        [ 0.34687157],
#        [ 0.19695216],
#        [ 0.96790415],
#        [-0.89906108],
#        [-0.1829535 ],
#        [-2.59377175],
#        [ 0.77134351],
#        [ 0.06866528],
#        [ 0.72972661]])

# %%
y
# Out:
# array([  9.89922787,   9.87890867,  27.27401162,  19.45536402,
#        -10.51115036,  18.54360382,  31.73249359, -10.6330512 ,
#          4.02117565,  12.27059626,   2.50801983,  -2.20689384,
#         -3.83871696, -24.42348319,  -6.58786708, -17.84163989,
#          6.23199324,  21.16669308,  -4.94862241, -11.85417842,
#          1.70305141,  14.58573816,   1.76214397,  -2.53088773,
#        -10.88131234,  -1.25087412,  -0.16694788,  -0.16755398,
#          0.35844289,  -5.21337477, -23.14666799,  -4.60706109,
#          3.02407907, -10.19332188,  -7.79663647,  24.31428296,
#         17.13833842,  -9.19589612,  10.89448656,  -3.39743006,
#         -6.63869174, -18.37902184, -22.2439088 , -14.43824872,
#        -28.35377235, -29.16280459,  12.70235909, -10.89404947,
#          2.47401804, -17.748093  , -33.70659524,  21.79852249,
#         -8.04847005, -12.13297604,  -8.81393604, -11.92201992,
#         -7.90285923,  21.36319099,  12.54460159,  -7.00637658,
#         -7.61187562,  12.47186037, -13.25740812,   3.15793787,
#        -10.83481634,   2.83807667,  24.47137452,  -0.22237451,
#          9.35281686,  34.47719987,  -0.80829281,   5.13270084,
#        -14.10719002,  14.8213225 ,  -5.06053669,   5.46711891,
#         26.09622754,  19.72845043,   7.56010003,  -0.86693516,
#         15.86491099, -13.12583073,  15.30077878,  14.17918066,
#         -0.7461081 ,  13.85780084,   2.24422818,  -1.11097129,
#          2.7056137 , -13.06281619,   3.76934507,   1.43618239,
#         -2.35154949,  14.30872484,  -6.51592328,  -6.72402916,
#        -39.13215616,  21.13933753,  -6.01274151,   0.36666658])

# %%
import matplotlib.pyplot as plt

plt.scatter(X, y)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(X,y)

m = model.coef_
print(m)
print(model.intercept_)
# Out:
# [14.24897833]
# 0.4142660590519824

# %%
class GDRegressor():

    def __init__(self, learning_rate, epochs):
        self.m = m
        self.b = -50
        self.lr = learning_rate
        self.epochs = epochs


    def fit(self, X, y):
        
        # Calculate b using GD

        for i in range(self.epochs):
            loss_slope = -2 * np.sum(y - self.m*X.ravel() - self.b)
            self.b = self.b - (self.lr * loss_slope)
            
            plt.plot(X, self.m * X + self.b)
            # print(self.b)

        plt.scatter(X, y)

        print(self.b)


    def predict(self, X_test):
        return self.m * X_test + self.b

# %%
model = GDRegressor(0.0001, 500)

model.fit(X, y)
# Out:
# 0.41219786495005567

# %%
plt.scatter(X, y)
plt.plot(X, model.predict(X), color='red')
