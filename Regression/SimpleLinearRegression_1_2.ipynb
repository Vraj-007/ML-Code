# %%
# Non-Closed form solution
# Using gradient descent
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('placement.csv')

# %%
# Plotting data points
plt.scatter(df['cgpa'], df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package')

# %%
# Creating X and y
X = df.iloc[:, 0:-1]
y = df.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split
# Train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 2)

# %%
from sklearn.linear_model import SGDRegressor

# %%
# Creating a object
model = SGDRegressor()
# Fitting training data
model.fit(X_train, y_train)
# Out:
# SGDRegressor()

# %%
# predict for different values
# Input size must be (1,1) --> 2D
# We have to reshape our input
model.predict(X_test)
# Out:
# array([3.70564401, 3.08616776, 2.53600353, 2.68329159, 1.9685113 ,
#        2.06381534, 2.29341143, 2.96053971, 3.60600797, 2.96487171,
#        3.86159607, 3.41106789, 2.99086372, 2.54899954, 3.15981179,
#        3.37641188, 2.19377539, 3.20313181, 2.99519572, 3.33742386,
#        2.67029559, 3.14248378, 2.90422368, 3.10782777, 3.54535995,
#        2.91288769, 3.39807189, 3.28110784, 3.72730402, 2.2067714 ,
#        3.51936793, 3.17713979, 3.58867996, 2.84790766, 2.84357566,
#        3.22479181, 3.4240639 , 2.71361561, 2.74827162, 2.79159164])

# %%
plt.scatter(df['cgpa'], df['package'])
# Plotting a line in data points
plt.plot(X_train, model.predict(X_train), color='red')
    
plt.xlabel('CGPA')
plt.ylabel('Package')
# Out:
# Text(0, 0.5, 'Package')

# %%
# Getting slope of line
model.coef_
# Out:
# array([0.43320018])

# %%
# Getting intercept of line
model.intercept_
# Out:
# array([-0.01121351])
