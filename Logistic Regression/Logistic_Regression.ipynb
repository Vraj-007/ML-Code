# %%
from sklearn.datasets import make_classification
import numpy as np

# %%
X, y = make_classification(n_samples=200, n_features=2, n_informative=2, n_redundant=0, n_classes=2, 
                            n_clusters_per_class=1, class_sep=5, hypercube=False, random_state=40)

# %%
import matplotlib.pyplot as plt

plt.scatter(X[:, 0], X[:, 1], c=y, cmap='winter', s=20)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

model.fit(X, y)
# Out:
# LogisticRegression()

# %%
m = -(model.coef_[0][0]/model.coef_[0][1])
b = -(model.intercept_/model.coef_[0][1])

# %%
x_input = np.linspace(-3, 3, 200) # 200 values between -5 and 7
y_input = m * x_input1 + b

# %%
plt.figure(figsize=(10, 6))
plt.plot(x_input, y_input, color='red', linewidth=2)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='winter', s=30)
plt.ylim(-3, 3) # y limits
# Out:
# (-3.0, 3.0)
