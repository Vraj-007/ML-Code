# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

# %%
from sklearn.datasets import make_circles

X, y = make_circles(200, factor=0.2, noise=0.15)

plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap='bwr')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model = SVC(kernel='linear')
model.fit(X_train, y_train.ravel())

from sklearn.metrics import r2_score

y_pred = model.predict(X_test)

print(f"r2 score : {r2_score(y_test, y_pred)}")
# Out:
# r2 score : -0.8045112781954891

# %%
# Applying Transformation on data

def plot_3D_plot(X, y):
    r = np.exp(-(X**2).sum(1))
    ax = plt.subplot(projection='3d')
    ax.scatter3D(X[:, 0], X[:, 1], r, c=y, s=40, cmap='bwr')
    return ax

plot_3D_plot(X_train, y_train)
# Out:
# <Axes3D: >

# %%
model = SVC(kernel='rbf')
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

print(f"r2 score : {r2_score(y_test, y_pred)}")
# Out:
# r2 score : 0.899749373433584
